# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(z, zp):
    mse = MSE = sum((z - zp)**2) / len(z)
    return mse
    """
    請完成這個 Function 後往下執行
    """

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 246.088
# The Mean absolute error is 12.467

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 我在Dataset裡面找到下面一組資料為
# ---
#
# US Public Assistance for Women and Children
# ---
#
# Where does it come from, who spends it, who gets it.
# ---
#
# 1. 你選的這組資料為何重要
#
#
# ---
# 探索美國公共援助的各個方面。顯示近年來的趨勢，更好地了解各州機構之間的差異。雖然聯邦政府贊助該計劃並提供資金，但計劃在州一級進行管理，並且可以廣泛變化。
# ---
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#
#
# ---
#
#
# 資料提供者：JohnM
# ---
#
# 　 　　　  　 Benbrook Analytics的負責人
# ---
#
# 　　　　　　Dallas - Fort Worth, Texas, United States
# ---
#
# 資料收集
# ---
#
# City and Town Population 2010-2016 from the US Census Bureau. See https://census.gov/data/tables/2016/demo/popest/total-cities-and-towns.html for methodology and additional data.
# ---
#
# 3. 蒐集而來的資料型態為何
#
#
# ---
#
# 資料檔案為csv檔，檔案裡面為各州之間，每個城市的貧困數據，數據從2013年到2016年。
# ---
#
#
# 4. 這組資料想解決的問題如何評估
# ---
#
#
# 這筆數據集可以從其他內容中獲得有關經濟學、其他人口統計學、行政費用等。因此可以透過稅收
# 和企業補貼，政府機構以及項目參與者來探索資金問題。
# ---
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ---
#
# 工資成本、物價越來越高，若是沒提升每個司機的載客率，以增加公司業績。車隊可能會面臨經營不善而倒閉。
# ---
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# ---
# (1). 透過App提供之使用者資訊及叫車資訊，收集使用自由車隊叫車服務的年齡層、性別、工作、教育水準。特別鎖定使用之客戶群。
# ---
#
# (2). 透過叫車服務的時間點，以及客戶需等待時間之平均值，來決定該地區可能需要的司機數，以便縮短客戶叫車的等待時間。
# ---
#
# (3). 透過歸納載客的地點及客戶下車地點，整合某些地區是否需要多一點的司機。
# ---
#
# 3. 蒐集而來的資料型態為何
# ---
# 可以針對需求的3點來整理資料型態，針對以下3點區分
# ---
# (1). 客戶基本資料
# ---
# (2). 針對時間
# ---
# (3). 針對地點
# ---
#
# ---
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# ---
# 可從單位時間內，所有司機的載客率平均，以及單位時間內，所有司機的總業績來評估。
# ---
